# %% [markdown]
# <a href="https://colab.research.google.com/github/GeovanaMeneguelliThomaz/INTMI_2025/blob/main/04_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 Peça um número e informe se ele é maior que 10. Crie um algoritmo em Python para fazer essa verificação.
x=int(input("digite um número"))
if x>10:
  print("Maior")
elif x == 0:
  print( "Zero")
else:
  print("Menor")
# Out:
# digite um número0
# Zero

# %%
# 2 Peça um número inteiro e informe se ele é par. Crie um algoritmo em Python que verifique se o número é divisível por 2.
número=int(input("digite um número"))
if número%2 == 0:
  print("Par")
else:
  print("Ímpar")
# Out:
# digite um número4
# Par

# %%
# 3 Peça um nome e informe se ele contém a letra "a". Crie um algoritmo em Python que faça essa verificação.
nome = input("Digite um nome: ")
nome_minusculo = nome.lower()
if 'a' in nome_minusculo:
    print("contém 'a' . ")
else:
    print("NÃO contém 'a' . ")
# Out:
# Digite um nome: lara
# contém 'a' .

# %%
# 4 Peça um número e informe se ele é múltiplo de 5. Crie um algoritmo em Python que verifique se o número é divisível por 5.
número=int(input("digite um número"))
if número%5 == 0:
  print("Divisível")
else:
  print("Não divisível")
# Out:
# digite um número35
# Divisível

# %%
# 5 Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos). Crie um algoritmo em Python para essa verificação.
x = int(input("Digite a temperatura atual em °C: "))
if x > 30:
  print('Quente')
else:
    print('frio')
# Out:
# Digite a temperatura atual em °C: 30
# frio

# %%
# 6 Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente. Crie um algoritmo em Python que faça essa validação e exiba a mensagem correta.
Opção=input(" Digite 'S' para continuar ou 'N' para sair: ")
if Opção == 'S':
  print("Ação: Continuar")
elif Opção == 'N':
  print("Ação: Sair")
else:
  print("Opçaõ inválida.Digite 'S' ou 'N' . ")
# Out:
#  Digite 'S' para continuar ou 'N' para sair: S
# Ação: Continuar

# %%
# 7 Peça um número e informe se ele é negativo, zero ou positivo. Crie um algoritmo em Python para classificar o número.
x=int(input("digite um número"))
if x>0:
  print("Positivo")
elif x == 0:
  print( "Zero")
else:
  print("Negativo")
# Out:
# digite um número7
# Positivo

# %%
# 8 Peça um número de 1 a 7 e informe o dia da semana correspondente. Crie um algoritmo em Python que associe o número ao dia correto.
numero = int(input("Digite um número de 1 a 7: "))
if numero == 1:
   print("O dia correspondente é Domingo")
elif numero == 2:
     print("O dia correspondente é Segunda-feira")
elif numero == 3:
     print("O dia correspondente é Terça-feira")
elif numero == 4:
     print("O dia correspondente é Quarta-feira")
elif numero == 5:
     print("O dia correspondente é Quinta-feira")
elif numero == 6:
     print("O dia correspondente é Sexta-feira")
elif numero == 7:
     print("O dia correspondente é Sábado")
else:
     print("Número inválido! Digite um valor entre 1 e 7.")
# Out:
# Digite um número de 1 a 7: 6
# O dia correspondente é Sexta-feira

# %%
# 9 Peça um ano e informe se ele é bissexto. Crie um algoritmo em Python que verifique se o ano é divisível por 4 e não por 100, exceto se também for divisível por 400.
ano= int(input("Digite um ano: "))
if (ano % 4 == 0 and ano % 100 !=0) or ( ano % 400 == 0 ):
  print((f"O ano é bissexto."))
else:
    print(f"O ano  não é bissexto.")
# Out:
# Digite um ano: 5098
# O ano  não é bissexto.

# %%
# 10 Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5). Crie um algoritmo em Python que realize esse cálculo corretamente.
horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas: "))
valor_por_hora = float(input("Digite o valor por hora: "))

if horas_trabalhadas <= 40:
    salario = horas_trabalhadas * valor_por_hora
else:
    salario_base = 40 * valor_por_hora
    horas_extras = horas_trabalhadas - 40
    valor_horas_extras = horas_extras * valor_por_hora * 1.5
    salario = salario_base + valor_horas_extras

print(f"O salário total é: R${salario:.2f}")
# Out:
# Digite a quantidade de horas trabalhadas: 45
# Digite o valor por hora: 67
# O salário total é: R$3182.50
